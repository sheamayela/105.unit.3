# %% [markdown]
# # Feeder 3.1 Data Compilation

# %% [markdown]
# ### Importing Pandas

# %% [markdown]
# #### Packages

# %% [markdown]
# This provides more tools and functions not available in Python. Anadacona includes a feature which the pandas package is already installed.

# %% [markdown]
# Once the package has been installed, you can now import your file in you current python session using the imported button. If the file is not imported it will not be recognized and functions will be unavailble.

# %% [markdown]
# #### Pandas

# %% [markdown]
# Pandas enables you to store data with feature such as rows, columns, and headers, which is similar to Microsoft Excel. This software is beneficial because it allows you to filter large datasets to the sepcific topics you are targeting. Pandas has a varitey of tools which you can use to manage large datasets.

# %% [markdown]
#  Make sure the file that you import is saved as .csv

# %% [markdown]
# You will import data file that we need to use with python. You will only be using pandas not numpys.

# %% [markdown]
# You will first type "import pandas" following with "as pd"

# %%
import pandas as pd

# %% [markdown]
# ### Creating a Dataframe

# %% [markdown]
# You should have downloaded the .csv file "CountyHealthData_2014-2015.csv". Store your copy in the same folder as this notebook. Save the document atleast one time into your directory.

# %% [markdown]
# Now you will create a dateframe object. your .csv file will be read by pandas.

# %% [markdown]
# #### Using pd.read_csv

# %% [markdown]
# pd.read_csv will read the data from your Comma Separated Values (csv) file. It will be defined as "df". Once you define the code, you will type "pd.read_csv" and inside the parenthesis and quotations you will type the entire name of the your .csv file.

# %%
df=pd.read_csv("CountyHealthData_2014-2015.csv")

# %% [markdown]
# ### Exploring our dataframe

# %% [markdown]
# The purpose of ".dtype" will show you all the columns and the types of columns.
# Type in the name of your new dta set "df" follow with .dtypes

# %% [markdown]
# Type in the the name of your new data set "df" follow with .dtypes

# %%
df.dtypes
# Out:
# State                                object
# Region                               object
# Division                             object
# County                               object
# FIPS                                  int64
#                                      ...
# Other primary care providers        float64
# Median household income               int64
# Children eligible for free lunch    float64
# Homicide rate                       float64
# Inadequate social support           float64
# Length: 64, dtype: object

# %% [markdown]
# The purpose of .shape is to show you the number of columns and the number of row in the data set.

# %% [markdown]
# Type the name of your define data set which is "df" following with .shape

# %%
df.shape
# Out:
# (6109, 64)

# %% [markdown]
# If you want to know the total count of cell in your data set you can use .size. This will give you the number of cells in the dataframe.

# %% [markdown]
# Type the name of your defined data set "df" followed with .shape.

# %%
df.size
# Out:
# 390976

# %% [markdown]
# If you want a preview of all the columns in you data set, .columns will reveal the title of each column in the data set.

# %% [markdown]
# Type the name of your define data set which is "df" following with .columns

# %%
df.columns
# Out:
# Index(['State', 'Region', 'Division', 'County', 'FIPS', 'GEOID', 'SMS Region',
#        'Year', 'Premature death', 'Poor or fair health',
#        'Poor physical health days', 'Poor mental health days',
#        'Low birthweight', 'Adult smoking', 'Adult obesity',
#        'Food environment index', 'Physical inactivity',
#        'Access to exercise opportunities', 'Excessive drinking',
#        'Alcohol-impaired driving deaths', 'Sexually transmitted infections',
#        'Teen births', 'Uninsured', 'Primary care physicians', 'Dentists',
#        'Mental health providers', 'Preventable hospital stays',
#        'Diabetic screening', 'Mammography screening', 'High school graduation',
#        'Some college', 'Unemployment', 'Children in poverty',
#        'Income inequality', 'Children in single-parent households',
#        'Social associations', 'Violent crime', 'Injury deaths',
#        'Air pollution - particulate matter', 'Drinking water violations',
# ...

# %% [markdown]
# If you want a preview of the first  5 columns in the dataset, you will use the code .head.

# %% [markdown]
# Type the name of your define data set which is "df" following with .head()

# %%
df.head()
# Out:
#   State Region Division                      County  FIPS  GEOID   SMS Region  \
# 0    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 1    AK   West  Pacific  Aleutians West Census Area  2016   2016  Insuff Data
# 2    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 3    AK   West  Pacific           Anchorage Borough  2020   2020    Region 22
# 4    AK   West  Pacific          Bethel Census Area  2050   2050  Insuff Data
#
#        Year  Premature death  Poor or fair health  ...  Drug poisoning deaths  \
# 0  1/1/2014              NaN                0.122  ...                    NaN
# 1  1/1/2015              NaN                0.122  ...                    NaN
# 2  1/1/2014           6827.0                0.125  ...                  15.37
# 3  1/1/2015           6856.0                0.125  ...                  17.08
# 4  1/1/2014          13345.0                0.211  ...                    NaN
#
# ...

# %% [markdown]
# ### Filtering Our Data

# %% [markdown]
# We want our data set to focus on areas in North Carolina and the effects of food insecurity on the health of the NC residences.

# %% [markdown]
# Since you want to filter the date to only states in North Carolina, you will want to use df["State"]. Then you will follow this with "==" and the desired state after which would be "NC".

# %%
df=df[df["State"] == "NC"]
df
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# You can check to see if your data was defined to your desire by typing in the name of your set. You would type "df"

# %%
df
# Out:
#      State Region        Division            County   FIPS  GEOID  \
# 3243    NC  South  South Atlantic   Alamance County  37001  37001
# 3244    NC  South  South Atlantic   Alamance County  37001  37001
# 3245    NC  South  South Atlantic  Alexander County  37003  37003
# 3246    NC  South  South Atlantic  Alexander County  37003  37003
# 3247    NC  South  South Atlantic  Alleghany County  37005  37005
# ...    ...    ...             ...               ...    ...    ...
# 3438    NC  South  South Atlantic     Wilson County  37195  37195
# 3439    NC  South  South Atlantic     Yadkin County  37197  37197
# 3440    NC  South  South Atlantic     Yadkin County  37197  37197
# 3441    NC  South  South Atlantic     Yancey County  37199  37199
# 3442    NC  South  South Atlantic     Yancey County  37199  37199
#
#        SMS Region      Year  Premature death  Poor or fair health  ...  \
# 3243    Region 20  1/1/2014           7123.0                0.192  ...
# ...

# %% [markdown]
# You want to filter the data to the column that you desire for your data table. In this case we want state, country, year, food enivornment index, adult obesity, limited access to healthy foods, diabetes, and food insecurity. You will use .loc[] and input all comun titles inside the brackets.

# %%
df=x.loc[:,["State","County", "Food environment index","Adult obesity","Limited access to healthy foods","Diabetes","Food insecurity"]]
df
# Out:
#      State            County  Food environment index  Adult obesity  \
# 3243    NC   Alamance County                   6.532          0.341
# 3244    NC   Alamance County                   6.200          0.332
# 3245    NC  Alexander County                   7.825          0.272
# 3246    NC  Alexander County                   7.400          0.283
# 3247    NC  Alleghany County                   7.561          0.247
# ...    ...               ...                     ...            ...
# 3438    NC     Wilson County                   5.900          0.373
# 3439    NC     Yadkin County                   8.296          0.297
# 3440    NC     Yadkin County                   8.000          0.301
# 3441    NC     Yancey County                   8.001          0.287
# 3442    NC     Yancey County                   7.700          0.271
#
#       Limited access to healthy foods  Diabetes  Food insecurity
# 3243                            0.113     0.124            0.174
# ...

# %% [markdown]
# ### Exporting Our New Subset

# %% [markdown]
# Now that we've finished manipulating out data sets we can export it as .csv file. This data will be accessible to the public.

# %% [markdown]
# We will export the manipulated dataset by using RI_subset.to_csv("RI_subset.csv"). You will add the file name inside the pararenthesis.

# %% [markdown]
# You will replace "RI_subset" with the name of your define data set. In this case it would be "df".

# %%
df.to_csv("df", index=False)
